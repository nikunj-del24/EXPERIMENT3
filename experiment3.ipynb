# %%
Nikunj Deep Upadhyay
25070123081
Study of tuple in python

# %%
tpl=(2,True,4.0,"Nikunj")
print(tpl)
# Out:
# (2, True, 4.0, 'Nikunj')

# %%
tpl2=("apple","banana","cherry")
print(tpl2[1])
print(tpl2[-2])
# Out:
# banana
# banana

# %%
tpl=("apple",2,"cherry",2.5)
print(tpl[2:5])
# Out:
# ('cherry', 2.5)

# %%
tpl=("a",)*2
print(tpl)
# Out:
# ('a', 'a')

# %%
tpl5=(10,)*5
print(tpl5)
# Out:
# (10, 10, 10, 10, 10)

# %%
a=("symbiosis",)*5
print(a)
# Out:
# ('symbiosis', 'symbiosis', 'symbiosis', 'symbiosis', 'symbiosis')

# %%
tpl6=(10)*5
print(tpl6)
# Out:
# 50

# %%
tpl7=("apple","banana","orange")
print("before:",id(tpl7))
tpl8=("kiwi",)
tpl7+=tpl8
print(tpl7)
print("after:",id(tpl7))
# Out:
# before: 136508809620800
# ('apple', 'banana', 'orange', 'kiwi')
# after: 136508809526016

# %%
tpl7=["apple","banana","orange"]
print("before:",id(tpl7))
tpl8=["kiwi",]
tpl7+=tpl8
print(tpl7)
print("after:",id(tpl7))
# Out:
# before: 136508354633024
# ['apple', 'banana', 'orange', 'kiwi']
# after: 136508354633024

# %%
marks=(90,82,66,76,33)
print(len(marks))
print(max(marks))
print(min(marks))
print(sum(marks))
print(sorted(marks))
print(sum(marks)/len(marks))
# Out:
# 5
# 90
# 33
# 347
# [33, 66, 76, 82, 90]
# 69.4

# %%
# result
result=("maths",72,"A")
# unpack the tuple
subject,marks,grade=result
# display the result details
print("subject:",subject)
print("marks:",marks)
print("grade:",grade)

if marks>=75:
  print("Distinction")
# Out:
# subject: maths
# marks: 72
# grade: A

# %%
Attendance=("P","A","P","A","P")
C=Attendance.count("P")
D=Attendance.count("A")
print("Total number of present days:",C)
print("Total number of absent days:",D)
# Out:
# Total number of present days: 3
# Total number of absent days: 2
